# %% [markdown]
# <a href="https://colab.research.google.com/github/ialhashim/DenseDepth/blob/master/DenseDepth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# %cd /content/gdrive/My\ Drive
# !ls
# !git clone https://github.com/ialhashim/DenseDepth.git
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# /content/gdrive/My Drive
#  07460727.pdf
#  08397108.pdf
#  12.zip
#  1311.2901.pdf
#  140247B_a03.docx.gdoc
#  140247B_Group07.gdoc
#  140247B.jpg
#  140247B_Report.docx
#  20929.pptx
# '2) Author biographies and photos.gdoc'
# '4 June Cropped rename.zip'
# 'Analysis Results for segementation.gslides'
# 'Applications of Random Matrix Theory.gslides'
#  Ass2.gsheet
# 'ass2_machine vision.docx'
# 'ass2_machine vision.docx.gdoc'
#  ASS2_vinoj.zip
#  Ass2.xlsx
#  Assignment_1_Superpixels_Vinoj.gdoc
#  Assignment_1_Superpixels_Vinoj.pdf
#  attrition.gdoc
# 'AutoRecovery save of 140247B_Report.docx'
# 'Battery free cellphone.gdoc'
#  best_weights_2.h5
#  best_weights.h5
#  CapsNet
# 'Colab Notebooks'
# 'Cone Segmentation 07072021.pptx'
# 'Copy of 5_140247B.pptx.gslides'
# 'Copy of ICASSP rebuttal.gdoc'
# 'Copy of Pose Detection.gslides'
# 'Copy of sharp stool update 15012021.gslides'
#  CVPR19-poster-template.gslides
#  cvpr.otp
#  DenseDepth
# 'Department Letter.docx'
# 'Department Letter.gdoc'
#  ecg
# 'ECG Capsules (1).zip'
# 'ECG Capsules.zip'
# 'econ assignment.gdoc'
#  Edits.gdoc
# 'experiment setup.gdraw'
# 'Eye Donation Campaign.docx'
#  eye_donation.pdf
# 'Final presentation.gslides'
#  First Order Filters _20161227172756.pdf
# 'Hirunima Jayasekara_CV (1).pdf'
# 'Hirunima Jayasekara_CV (2).pdf'
# 'Hirunima Jayasekara_CV - Nipuni Hirunima (1).pdf'
# 'Hirunima Jayasekara_CV - Nipuni Hirunima.pdf'
# 'Hirunima Jayasekara_CV.pdf'
# 'Hirunima Jayasekara.zip'
# 'Hirunima PHD.gsheet'
#  hjayasekra.zip
#  IAS
# 'ICAART Rebuttal.gdoc'
# 'ICAART rebuttal original.gdoc'
# 'ICASSP rebuttal.gdoc'
# 'invitaion to society.docx'
#  IOT.zip
#  itinerary_usa.gsheet
#  jaks
# 'Journal Bio.gdoc'
#  June4_070720.gslides
#  June4_070720.pptx
#  June4_210720.gslides
# 'linear algebra'
# 'literature deep model.gdoc'
#  LMRL_2020_Poster_ID_8.pdf
# 'MA 2033 - Linear Algebra (Part 1).pdf'
# 'MA 2033 - Linear Algebra (Part 2).pdf'
# 'Machine vision'
# 'major gpa.gsheet'
#  matlab
# 'meta_test_data_benign_sort_all (1).pickle'
#  meta_test_data_benign_sort_all.pickle
# 'meta_test_data_sort_all (1).pickle'
#  meta_test_data_sort_all.pickle
# 'meta_train_data_benign_sort_all (1).pickle'
#  meta_train_data_benign_sort_all.pickle
#  meta_train_data_sort_all_7.csv
# 'meta_val_data_sort_all (1).pickle'
#  meta_val_data_sort_all.pickle
#  MIT.gdoc
#  mk1.pdf
#  MK1.tex
# 'Models+Results for segmentation 130920.gslides'
# 'monthly reports'
# 'more samples (1).zip'
# 'more samples.zip'
# 'MS MAWANANE.gdoc'
#  NIPS19-poster
#  NIPS2020-poster-landscape.pptx
# 'Non Technical Paper Review.gdoc'
#  Nosql.gdoc
# 'office desktop'
# 'Official Rental Application.docx'
#  OSEP_Application_2018-06-07.doc
# 'Paper Review -Mercon.gdoc'
# 'places i wanna go.gdoc'
#  player2.csv
#  player2.csv.gsheet
# 'Pose Detection.gslides'
#  poster_ECG.gslides
#  problem-sheet2..pdf
#  processor
#  processor.gdraw
# 'Project report_140113L_140247B_140257F_140271R (1).docx.gdoc'
# 'Project report_140113L_140247B_140257F_140271R (2).docx.gdoc'
# 'Project report_140113L_140247B_140257F_140271R.docx'
# 'Project report_140113L_140247B_140257F_140271R.docx.gdoc'
#  purtabation_lot_of_samples.zip
#  purtabation.zip
#  README.gdoc
# 'Recommendation draft Prof Jie.gdoc'
# 'Recommendation_Draft_Prof_Ren_v2 (1).gdoc'
#  Recommendation_Draft_Prof_Ren_v2.docx
#  Recommendation_Draft_Prof_Ren_v2.gdoc
# 'Recommendation draft Prof Yuen.gdoc'
#  related_vinoj_paper.gdoc
#  Report6.docx.gdoc
#  Report.pdf
# 'report tronic.gdoc'
# 'request to enroll for a module.gdoc'
# 'Results for segementation.gslides'
# 'Results for segmentation 030920.gslides'
# 'Results for segmentation 060820 modified.gslides'
# 'Results for segmentation 090820 modified.gslides'
# 'Results for segmentation 100820.gslides'
# 'Results for segmentation 120820.gslides'
# 'Results for segmentation 160920.gslides'
# 'Results for segmentation 180820 modified.gslides'
# 'Results for segmentation 240820.gslides'
# 'Results for segmentation 250920.gslides'
# 'Results for segmentation 250920_old.gslides'
# 'Results for segmentation 310820.gslides'
#  Review.gdoc
# 'review papers.gdoc'
#  roi_sorted.zip
# 'sensors whatever this is.gdoc'
# 'sharp stool_sept 2020 update.pptx'
# 'sharp stool update 04012021.gslides'
# 'sharp stool update 04022021.gslides'
# 'sharp stool update 05022021.pptx'
# 'sharp stool update 07032021.pptx'
# 'sharp stool update 15102020.gslides'
# 'sharp stool update 15122020.gslides'
# 'sharp stool update 23102020.gslides'
# 'sharp stool update 28122020_modify.gslides'
# 'sharp stool update 31102020.gslides'
# 'sharp stool update 5102020.gslides'
# 'SOP - points.gdoc'
#  st_class.zip
#  Stool_Classification_020620.gslides
#  Stool_Classification_020720.gslides
# 'Stool_Classification_020720 yc.pptx'
#  Stool_Classification_050720.gslides
#  Stool_Classification_070520.gslides
# 'Stool Classification_070720.gslides'
# 'Stool Classification_110720.gslides'
# 'Stool_Classification_150620 (1).gslides'
#  Stool_Classification_150620.gslides
#  Stool_Classification_180520.gslides
#  Stool_Classification_250420.pptx
#  Stool_Classification_250620.gslides
#  Stool_Classification_290620.gslides
#  Stool_Classification_310620.gslides
# 'stool samples.zip'
# 'SUTD_Research Hiring Requisition Form V3 - keysight nipuni.docx'
# 'SUTD_Research Hiring Requisition Form V3 - keysight nipuni.gdoc'
#  Technical_Assignment_hirunima_jayasekara.zip
#  test.zip
#  tmprvd4yqgf.pdf
#  train.zip
#  tronic.zip
# 'Ubuntu conda Installation Guide.gdoc'
# 'UMD Zoom directory.xlsx'
# 'Untitled document (1).gdoc'
# 'Untitled document.gdoc'
# 'Untitled form (Responses).gsheet'
# 'Untitled presentation (1).gslides'
# 'Untitled presentation.gslides'
# 'Untitled spreadsheet.gsheet'
# 'Unversities second time.gsheet'
# 'Use docker to run your code.gdoc'
#  UW.gdoc
#  v1
#  WACV_vinoj.gslides
#  WACV_vinoj.pptx
#  wave_xception.py
# 'WhatsApp Image 2019-03-02 at 19.03.11.jpeg'
# 'WiFi fingerprint.gform'
# 'WP2 2021-03.pptx'
# 'WP3 2021-01.pptx'
# 'WP3 2021-02.gslides'
#  wrfe5t5gertgetgwrtwrt.zip

# %%
# %cd ./DenseDepth/PyTorch 

from matplotlib import pyplot as plt
from skimage import io
import numpy as np
from PIL import Image
import os
# !ls 
# !pip install tensorboardX
# !wget https://drive.google.com/file/d/1fdFu5NGXe4rTLYKD5wOqk9dl-eJOefXo/view?usp=sharing -O ./nyu_data.zip

# !python train_new_load_data.py #--epochs 2 #--data nyu --gpus 1 --bs 8
# Out:
# /content/gdrive/My Drive/DenseDepth/PyTorch
# data.py					 pytorch_model_skip_kanade.py
# load_weight_from_keras_pass_to_model.py  pytorch_model_skip.py
# load_weight_from_keras.py		 runs
# loss.py					 test.png
# model_0.pth				 train_new_load_data.py
# nyu_data.zip				 train_new.py
# __pycache__				 train.py
# pytorch_model.py			 utils.py
# Namespace(input='/content/gdrive/My\\ Drive/data/manual_0/images/img__0_1549119348321541200.png', model='../nyu.h5')
# Loading model...
# Model created.
# odict_keys(['encoder.original_model.features.conv0.weight', 'encoder.original_model.features.norm0.weight', 'encoder.original_model.features.norm0.bias', 'encoder.original_model.features.norm0.running_mean', 'encoder.original_model.features.norm0.running_var', 'encoder.original_model.features.norm0.num_batches_tracked', 'encoder.original_model.features.denseblock1.denselayer1.norm1.weight', 'encoder.original_model.features.denseblock1.denselayer1.norm1.bias', 'encoder.original_model.features.denseblock1.denselayer1.norm1.running_mean', 'encoder.original_model.features.denseblock1.denselayer1.norm1.running_var', 'encoder.original_model.features.denseblock1.denselayer1.norm1.num_batches_tracked', 'encoder.original_model.features.denseblock1.denselayer1.conv1.weight', 'encoder.original_model.features.denseblock1.denselayer1.norm2.weight', 'encoder.original_model.features.denseblock1.denselayer1.norm2.bias', 'encoder.original_model.features.denseblock1.denselayer1.norm2.running_mean', 'encoder.original_model.features.denseblock1.denselayer1.norm2.running_var', 'encoder.original_model.features.denseblock1.denselayer1.norm2.num_batches_tracked', 'encoder.original_model.features.denseblock1.denselayer1.conv2.weight', 'encoder.original_model.features.denseblock1.denselayer2.norm1.weight', 'encoder.original_model.features.denseblock1.denselayer2.norm1.bias', 'encoder.original_model.features.denseblock1.denselayer2.norm1.running_mean', 'encoder.original_model.features.denseblock1.denselayer2.norm1.running_var', 'encoder.original_model.features.denseblock1.denselayer2.norm1.num_batches_tracked', 'encoder.original_model.features.denseblock1.denselayer2.conv1.weight', 'encoder.original_model.features.denseblock1.denselayer2.norm2.weight', 'encoder.original_model.features.denseblock1.denselayer2.norm2.bias', 'encoder.original_model.features.denseblock1.denselayer2.norm2.running_mean', 'encoder.original_model.features.denseblock1.denselayer2.norm2.running_var', 'encoder.original_model.features.denseblock1.denselayer2.norm2.num_batches_tracked', 'encoder.original_model.features.denseblock1.denselayer2.conv2.weight', 'encoder.original_model.features.denseblock1.denselayer3.norm1.weight', 'encoder.original_model.features.denseblock1.denselayer3.norm1.bias', 'encoder.original_model.features.denseblock1.denselayer3.norm1.running_mean', 'encoder.original_model.features.denseblock1.denselayer3.norm1.running_var', 'encoder.original_model.features.denseblock1.denselayer3.norm1.num_batches_tracked', 'encoder.original_model.features.denseblock1.denselayer3.conv1.weight', 'encoder.original_model.features.denseblock1.denselayer3.norm2.weight', 'encoder.original_model.features.denseblock1.denselayer3.norm2.bias', 'encoder.original_model.features.denseblock1.denselayer3.norm2.running_mean', 'encoder.original_model.features.denseblock1.denselayer3.norm2.running_var', 'encoder.original_model.features.denseblock1.denselayer3.norm2.num_batches_tracked', 'encoder.original_model.features.denseblock1.denselayer3.conv2.weight', 'encoder.original_model.features.denseblock1.denselayer4.norm1.weight', 'encoder.original_model.features.denseblock1.denselayer4.norm1.bias', 'encoder.original_model.features.denseblock1.denselayer4.norm1.running_mean', 'encoder.original_model.features.denseblock1.denselayer4.norm1.running_var', 'encoder.original_model.features.denseblock1.denselayer4.norm1.num_batches_tracked', 'encoder.original_model.features.denseblock1.denselayer4.conv1.weight', 'encoder.original_model.features.denseblock1.denselayer4.norm2.weight', 'encoder.original_model.features.denseblock1.denselayer4.norm2.bias', 'encoder.original_model.features.denseblock1.denselayer4.norm2.running_mean', 'encoder.original_model.features.denseblock1.denselayer4.norm2.running_var', 'encoder.original_model.features.denseblock1.denselayer4.norm2.num_batches_tracked', 'encoder.original_model.features.denseblock1.denselayer4.conv2.weight', 'encoder.original_model.features.denseblock1.d ...
# available so uploading that sht encoder.original_model.features.conv0.weight
# available so uploading that sht encoder.original_model.features.norm0.weight
# available so uploading that sht encoder.original_model.features.norm0.bias
# available so uploading that sht encoder.original_model.features.norm0.running_mean
# available so uploading that sht encoder.original_model.features.norm0.running_var
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer1.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer1.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer1.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer1.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer1.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer1.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer1.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer1.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer1.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer1.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer2.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer2.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer2.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer2.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer2.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer2.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer2.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer2.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer2.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer2.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer3.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer3.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer3.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer3.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer3.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer3.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer3.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer3.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer3.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer3.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer4.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer4.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer4.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer4.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer4.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer4.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer4.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer4.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer4.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer4.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer5.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer5.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer5.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer5.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer5.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer5.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer5.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer5.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer5.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer5.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer6.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer6.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer6.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer6.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer6.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer6.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer6.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer6.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer6.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock1.denselayer6.conv2.weight
# available so uploading that sht encoder.original_model.features.transition1.norm.weight
# available so uploading that sht encoder.original_model.features.transition1.norm.bias
# available so uploading that sht encoder.original_model.features.transition1.norm.running_mean
# available so uploading that sht encoder.original_model.features.transition1.norm.running_var
# available so uploading that sht encoder.original_model.features.transition1.conv.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer1.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer1.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer1.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer1.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer1.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer1.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer1.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer1.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer1.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer1.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer2.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer2.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer2.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer2.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer2.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer2.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer2.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer2.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer2.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer2.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer3.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer3.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer3.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer3.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer3.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer3.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer3.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer3.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer3.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer3.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer4.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer4.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer4.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer4.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer4.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer4.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer4.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer4.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer4.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer4.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer5.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer5.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer5.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer5.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer5.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer5.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer5.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer5.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer5.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer5.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer6.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer6.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer6.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer6.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer6.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer6.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer6.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer6.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer6.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer6.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer7.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer7.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer7.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer7.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer7.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer7.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer7.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer7.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer7.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer7.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer8.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer8.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer8.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer8.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer8.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer8.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer8.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer8.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer8.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer8.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer9.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer9.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer9.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer9.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer9.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer9.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer9.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer9.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer9.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer9.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer10.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer10.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer10.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer10.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer10.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer10.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer10.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer10.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer10.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer10.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer11.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer11.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer11.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer11.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer11.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer11.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer11.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer11.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer11.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer11.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer12.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer12.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer12.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer12.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer12.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer12.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer12.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer12.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer12.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock2.denselayer12.conv2.weight
# available so uploading that sht encoder.original_model.features.transition2.norm.weight
# available so uploading that sht encoder.original_model.features.transition2.norm.bias
# available so uploading that sht encoder.original_model.features.transition2.norm.running_mean
# available so uploading that sht encoder.original_model.features.transition2.norm.running_var
# available so uploading that sht encoder.original_model.features.transition2.conv.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer1.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer1.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer1.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer1.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer1.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer1.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer1.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer1.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer1.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer1.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer2.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer2.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer2.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer2.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer2.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer2.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer2.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer2.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer2.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer2.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer3.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer3.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer3.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer3.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer3.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer3.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer3.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer3.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer3.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer3.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer4.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer4.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer4.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer4.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer4.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer4.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer4.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer4.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer4.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer4.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer5.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer5.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer5.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer5.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer5.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer5.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer5.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer5.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer5.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer5.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer6.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer6.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer6.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer6.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer6.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer6.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer6.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer6.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer6.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer6.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer7.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer7.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer7.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer7.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer7.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer7.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer7.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer7.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer7.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer7.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer8.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer8.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer8.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer8.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer8.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer8.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer8.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer8.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer8.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer8.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer9.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer9.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer9.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer9.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer9.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer9.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer9.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer9.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer9.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer9.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer10.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer10.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer10.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer10.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer10.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer10.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer10.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer10.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer10.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer10.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer11.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer11.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer11.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer11.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer11.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer11.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer11.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer11.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer11.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer11.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer12.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer12.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer12.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer12.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer12.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer12.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer12.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer12.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer12.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer12.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer13.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer13.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer13.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer13.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer13.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer13.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer13.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer13.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer13.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer13.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer14.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer14.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer14.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer14.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer14.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer14.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer14.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer14.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer14.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer14.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer15.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer15.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer15.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer15.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer15.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer15.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer15.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer15.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer15.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer15.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer16.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer16.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer16.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer16.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer16.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer16.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer16.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer16.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer16.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer16.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer17.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer17.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer17.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer17.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer17.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer17.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer17.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer17.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer17.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer17.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer18.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer18.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer18.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer18.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer18.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer18.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer18.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer18.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer18.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer18.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer19.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer19.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer19.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer19.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer19.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer19.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer19.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer19.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer19.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer19.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer20.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer20.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer20.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer20.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer20.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer20.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer20.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer20.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer20.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer20.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer21.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer21.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer21.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer21.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer21.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer21.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer21.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer21.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer21.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer21.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer22.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer22.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer22.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer22.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer22.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer22.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer22.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer22.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer22.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer22.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer23.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer23.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer23.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer23.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer23.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer23.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer23.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer23.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock3.denselayer23.norm2.running_var
# ...
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer22.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer22.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer23.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer23.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer23.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer23.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer23.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer23.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer23.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer23.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer23.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer23.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer24.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer24.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer24.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer24.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer24.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer24.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer24.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer24.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer24.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer24.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer25.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer25.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer25.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer25.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer25.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer25.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer25.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer25.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer25.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer25.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer26.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer26.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer26.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer26.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer26.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer26.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer26.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer26.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer26.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer26.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer27.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer27.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer27.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer27.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer27.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer27.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer27.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer27.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer27.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer27.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer28.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer28.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer28.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer28.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer28.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer28.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer28.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer28.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer28.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer28.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer29.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer29.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer29.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer29.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer29.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer29.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer29.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer29.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer29.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer29.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer30.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer30.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer30.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer30.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer30.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer30.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer30.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer30.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer30.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer30.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer31.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer31.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer31.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer31.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer31.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer31.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer31.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer31.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer31.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer31.conv2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer32.norm1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer32.norm1.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer32.norm1.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer32.norm1.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer32.conv1.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer32.norm2.weight
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer32.norm2.bias
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer32.norm2.running_mean
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer32.norm2.running_var
# available so uploading that sht encoder.original_model.features.denseblock4.denselayer32.conv2.weight
# available so uploading that sht encoder.original_model.features.norm5.weight
# available so uploading that sht encoder.original_model.features.norm5.bias
# available so uploading that sht encoder.original_model.features.norm5.running_mean
# available so uploading that sht encoder.original_model.features.norm5.running_var
# available so uploading that sht encoder.original_model.classifier.weight
# available so uploading that sht encoder.original_model.classifier.bias
# available so uploading that sht decoder.conv2.weight
# available so uploading that sht decoder.conv2.bias
# available so uploading that sht decoder.conv3.weight
# available so uploading that sht decoder.conv3.bias
# odict_keys(['encoder.original_model.features.conv0.weight', 'encoder.original_model.features.norm0.weight', 'encoder.original_model.features.norm0.bias', 'encoder.original_model.features.norm0.running_mean', 'encoder.original_model.features.norm0.running_var', 'encoder.original_model.features.norm0.num_batches_tracked', 'encoder.original_model.features.denseblock1.denselayer1.norm1.weight', 'encoder.original_model.features.denseblock1.denselayer1.norm1.bias', 'encoder.original_model.features.denseblock1.denselayer1.norm1.running_mean', 'encoder.original_model.features.denseblock1.denselayer1.norm1.running_var', 'encoder.original_model.features.denseblock1.denselayer1.norm1.num_batches_tracked', 'encoder.original_model.features.denseblock1.denselayer1.conv1.weight', 'encoder.original_model.features.denseblock1.denselayer1.norm2.weight', 'encoder.original_model.features.denseblock1.denselayer1.norm2.bias', 'encoder.original_model.features.denseblock1.denselayer1.norm2.running_mean', 'encoder.original_model.features.denseblock1.denselayer1.norm2.running_var', 'encoder.original_model.features.denseblock1.denselayer1.norm2.num_batches_tracked', 'encoder.original_model.features.denseblock1.denselayer1.conv2.weight', 'encoder.original_model.features.denseblock1.denselayer2.norm1.weight', 'encoder.original_model.features.denseblock1.denselayer2.norm1.bias', 'encoder.original_model.features.denseblock1.denselayer2.norm1.running_mean', 'encoder.original_model.features.denseblock1.denselayer2.norm1.running_var', 'encoder.original_model.features.denseblock1.denselayer2.norm1.num_batches_tracked', 'encoder.original_model.features.denseblock1.denselayer2.conv1.weight', 'encoder.original_model.features.denseblock1.denselayer2.norm2.weight', 'encoder.original_model.features.denseblock1.denselayer2.norm2.bias', 'encoder.original_model.features.denseblock1.denselayer2.norm2.running_mean', 'encoder.original_model.features.denseblock1.denselayer2.norm2.running_var', 'encoder.original_model.features.denseblock1.denselayer2.norm2.num_batches_tracked', 'encoder.original_model.features.denseblock1.denselayer2.conv2.weight', 'encoder.original_model.features.denseblock1.denselayer3.norm1.weight', 'encoder.original_model.features.denseblock1.denselayer3.norm1.bias', 'encoder.original_model.features.denseblock1.denselayer3.norm1.running_mean', 'encoder.original_model.features.denseblock1.denselayer3.norm1.running_var', 'encoder.original_model.features.denseblock1.denselayer3.norm1.num_batches_tracked', 'encoder.original_model.features.denseblock1.denselayer3.conv1.weight', 'encoder.original_model.features.denseblock1.denselayer3.norm2.weight', 'encoder.original_model.features.denseblock1.denselayer3.norm2.bias', 'encoder.original_model.features.denseblock1.denselayer3.norm2.running_mean', 'encoder.original_model.features.denseblock1.denselayer3.norm2.running_var', 'encoder.original_model.features.denseblock1.denselayer3.norm2.num_batches_tracked', 'encoder.original_model.features.denseblock1.denselayer3.conv2.weight', 'encoder.original_model.features.denseblock1.denselayer4.norm1.weight', 'encoder.original_model.features.denseblock1.denselayer4.norm1.bias', 'encoder.original_model.features.denseblock1.denselayer4.norm1.running_mean', 'encoder.original_model.features.denseblock1.denselayer4.norm1.running_var', 'encoder.original_model.features.denseblock1.denselayer4.norm1.num_batches_tracked', 'encoder.original_model.features.denseblock1.denselayer4.conv1.weight', 'encoder.original_model.features.denseblock1.denselayer4.norm2.weight', 'encoder.original_model.features.denseblock1.denselayer4.norm2.bias', 'encoder.original_model.features.denseblock1.denselayer4.norm2.running_mean', 'encoder.original_model.features.denseblock1.denselayer4.norm2.running_var', 'encoder.original_model.features.denseblock1.denselayer4.norm2.num_batches_tracked', 'encoder.original_model.features.denseblock1.denselayer4.conv2.weight', 'encoder.original_model.features.denseblock1.d ...
# Loading dataset zip file...Loaded (50688).
# Epoch: [0][0/12672]	Time 2.013 (2.013)	ETA 7:05:11	Loss 0.8492 (0.8492)
# Epoch: [0][100/12672]	Time 1.914 (192.544)	ETA 6:41:06	Loss 0.0402 (0.1165)
# Epoch: [0][200/12672]	Time 1.917 (383.003)	ETA 6:38:33	Loss 0.0510 (0.0908)
# Epoch: [0][300/12672]	Time 1.908 (573.397)	ETA 6:33:22	Loss 0.0439 (0.0802)
# Epoch: [0][400/12672]	Time 1.895 (763.652)	ETA 6:27:38	Loss 0.0480 (0.0730)
# Epoch: [0][500/12672]	Time 1.916 (954.006)	ETA 6:28:38	Loss 0.0366 (0.0710)
# Epoch: [0][600/12672]	Time 1.912 (1144.448)	ETA 6:24:41	Loss 0.0711 (0.0689)
# Epoch: [0][700/12672]	Time 1.908 (1334.811)	ETA 6:20:39	Loss 0.0326 (0.0667)
